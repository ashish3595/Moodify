# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
CLIENT_ID = "2db33da4dc4e45a3ad9d14500371bf81"
CLIENT_SECRET = "a07c6a2056aa4454a1a2d5f94900dd8d"
sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))

# %%
def analyze_playlist(user_id, playlist_id):
    playlist_features_list = ["artist","album","track_name", "track_id", "popularity", "danceability","energy","key","loudness","mode", "speechiness","acousticness",
                              "instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]
    playlist_df = pd.DataFrame(columns = playlist_features_list)
    # Loop through every track in the playlist, extract features and append the features to the playlist df

    playlist = sp.user_playlist_tracks(user_id, playlist_id)["tracks"]["items"]
    for track in playlist:
        
        # Create empty dict
        playlist_features = {}
        
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        playlist_features["popularity"] = track["track"]["popularity"]
        
        # print(track)
        
        # Get audio features
        audio_features = sp.audio_features(playlist_features["track_id"])[0]
        
        # print(audio_features)
        
        for feature in playlist_features_list[5:]:
            playlist_features[feature] = audio_features[feature]

        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
        
    return playlist_df

# %%
playlist_df = analyze_playlist("0cennos3iua0u6lvhcle1x707", "5wrnNtjBQ3JawfRur0mvun?si=bd13ac2cd43644ed")

# %%
playlist_df.head()
# Out:
#             artist                         album  \
# 0  Aura Da Prophet                           Fly
# 1  Aura Da Prophet                 Metamorphosis
# 2  Aura Da Prophet               Smoke That Good
# 3  Aura Da Prophet  The Plot to Self Destruction
# 4  Aura Da Prophet                       Oneness
#
#                      track_name                track_id popularity  \
# 0                           Fly  1KtiWNj2Q70JC0NYQnh7i8         29
# 1                 Metamorphosis  18Cv0XFfUPEVtDS9GBD65t         42
# 2               Smoke That Good  6HmtDr8q2kPiNZSYIG9epI         18
# 3  The Plot to Self Destruction  2lBLndanbhInzMtjeTexKB         43
# 4                       Oneness  6l1tOOMeoFPGYPJbIwkAGR         15
#
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.684   0.542  10   -10.147    0       0.1570        0.1210
# 1         0.580   0.727   2   -12.499    1       0.3340        0.5240
# ...
